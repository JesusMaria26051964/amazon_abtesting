# %% [markdown]
# # Cosas a limpiar
#
# - **Visit Date** -> Cambiar a tipo fecha
# - **Conversion** -> ???
# - **Product Category** -> Cambiar a MINUS
# Cambiar FASHHION a FASHION
# - **Product Id** -> Cambia a NUMERICO
# - **Price** -> Tiene NULOS, Cambiar COMAS por PUNTOS y cambiar tipo FLOAT
# - **Discount** -> Tiene NULOS, Cambiar COMAS por PUNTOS y cambiar tipo FLOAT
# - **Total Value** -> Cambiar COMAS por PUNTOS y cambiar tipo FLOAT
# - **Payment Method** -> Tiene NULOS
# Cambiar ESPACIOS por "_"
# - **Shipping Method** -> Tiene NULOS
# Cambiar ESPACIOS por "_"
# - **Customer Age** -> Tiene NULOS
# - **Device** -> Cambiar a MINUS
# - **Coupon Used** -> Tiene NULOS
# - **Browser** -> Cambiar categorias porque estan mal escritas
# - **Referrral Source** -> Cambiar categorias porque estan mal escritas
# Cambiar a MINUS

# %%
import pandas as pd
df_raw = pd.read_csv('../data/data_raw.csv')
df_raw.sample(5)
# Out:
#       User Id Group  Visit Date  Conversion Product Category Product Id  \
# 1883     1884     B  2022-01-29           0      ELECTRONICS      P1642
# 1530     1531     A  2022-03-20           0             TOYS      P1472
# 879       880     A  2022-01-09           0           SPORTS      P1056
# 1712     1713     B  2022-01-30           0      ELECTRONICS      P1500
# 5           6     A  2022-03-21           0         FASHHION      P1931
#
#        Product Name  Quantity   Price Discount  ... Payment Method  \
# 1883     Smartphone         0  432,63     0,07  ...            NaN
# 1530     Board Game         0    88,9     0,19  ...            NaN
# 879   Tennis Racket         0   82,15     0,25  ...            NaN
# 1712         Camera         0  366,69      0,2  ...            NaN
# 5             Dress         0   24,73     0,04  ...            NaN
#
#      Shipping Method   Region Customer Age  Customer Gender   Device  \
# ...

# %% [markdown]
# ### COPIA DEL DATAFRAME ORIGINAL ###

# %%
df = df_raw.copy()

# %% [markdown]
# ### CAMBIO NOMBRES DE COLUMNAS ###

# %%
df.columns = df.columns.str.replace(' ','_').str.lower()
df.sample(5)
# Out:
#       user_id group  visit_date  conversion product_category product_id  \
# 670       671     A  2022-01-12           0           BEAUTY      P1681
# 1054     1055     B  2022-01-15           0      ELECTRONICS      P1427
# 1690     1691     A  2022-01-05           0             HOME      P1974
# 26         27     A  2022-02-01           0             HOME      P1665
# 1028     1029     A  2022-03-16           0      ELECTRONICS      P1191
#
#      product_name  quantity   price discount  ... payment_method  \
# 670       Perfume         0   59,59     0,24  ...            NaN
# 1054   Headphones         0  811,91     0,07  ...            NaN
# 1690        Table         0  177,83      NaN  ...            NaN
# 26          Table         0  133,22     0,27  ...            NaN
# 1028       Laptop         0  263,05     0,13  ...            NaN
#
#      shipping_method region customer_age  customer_gender   device  \
# 670              NaN  South         51.0                M   TABLET
# ...

# %% [markdown]
# ### CAMBIAR VISIT_DATE A FECHAS ###

# %%
df['visit_date'] = pd.to_datetime(df['visit_date'], format='%Y-%m-%d')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   user_id           2000 non-null   int64
#  1   group             2000 non-null   object
#  2   visit_date        2000 non-null   datetime64[ns]
#  3   conversion        2000 non-null   int64
#  4   product_category  2000 non-null   object
#  5   product_id        2000 non-null   object
#  6   product_name      2000 non-null   object
#  7   quantity          2000 non-null   int64
#  8   price             1960 non-null   object
#  9   discount          1960 non-null   object
#  10  total_value       2000 non-null   object
#  11  payment_method    247 non-null    object
#  12  shipping_method   247 non-null    object
#  13  region            2000 non-null   object
#  14  customer_age      1960 non-null   float64
#  15  customer_gender   2000 non-null   object
# ...

# %% [markdown]
# ### crear una columna nueva ###

# %%
df['conversion_str'] = df['conversion'].apply(lambda x: 'yes' if x == 1 else 'no')
df.sample(10)
# Out:
#       user_id group visit_date  conversion product_category product_id  \
# 881       882     B 2022-02-03           0             HOME      P1348
# 795       796     B 2022-03-07           0      ELECTRONICS      P1288
# 1847     1848     A 2022-03-19           0         FASHHION      P1929
# 291       292     A 2022-02-17           0            BOOKS      P1109
# 715       716     B 2022-03-04           0         FASHHION      P1939
# 1481     1482     A 2022-02-18           0           SPORTS      P1246
# 664       665     A 2022-01-19           0      ELECTRONICS      P1417
# 377       378     A 2022-01-29           0           SPORTS      P1836
# 1425     1426     B 2022-01-27           0           SPORTS      P1382
# 1523     1524     A 2022-03-09           0           SPORTS      P1457
#
#        product_name  quantity   price discount  ... shipping_method   region  \
# 881           Chair         0   92,06     0,27  ...             NaN    South
# ...

# %% [markdown]
# ### sacar solo unas columnas ###

# %%
df.loc[:,['conversion','conversion_str']]
# Out:
#       conversion conversion_str
# 0              0             no
# 1              0             no
# 2              0             no
# 3              1            yes
# 4              0             no
# ...          ...            ...
# 1995           0             no
# 1996           0             no
# 1997           0             no
# 1998           0             no
# 1999           0             no
#
# [2000 rows x 2 columns]

# %% [markdown]
# ### cambia a MINUSCULAS ###

# %%
df['product_category']= df['product_category'].str.lower()

# %% [markdown]
# ### CAMBIAR FASHHION por FASHION ###

# %%
df['product_category']= df['product_category'].str.replace('fashhion','fashion')
df['product_category'].value_counts()
# Out:
# product_category
# fashion        321
# books          291
# home           287
# sports         282
# toys           276
# electronics    275
# beauty         268
# Name: count, dtype: int64

# %% [markdown]
# ### cambiar a numero ###

# %%
df['product_id']= df['product_id'].str.replace('P','')
df.sample(5)
df['product_id']= df['product_id'].astype('int64')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   user_id           2000 non-null   int64
#  1   group             2000 non-null   object
#  2   visit_date        2000 non-null   datetime64[ns]
#  3   conversion        2000 non-null   int64
#  4   product_category  2000 non-null   object
#  5   product_id        2000 non-null   int64
#  6   product_name      2000 non-null   object
#  7   quantity          2000 non-null   int64
#  8   price             1960 non-null   object
#  9   discount          1960 non-null   object
#  10  total_value       2000 non-null   object
#  11  payment_method    247 non-null    object
#  12  shipping_method   247 non-null    object
#  13  region            2000 non-null   object
#  14  customer_age      1960 non-null   float64
#  15  customer_gender   2000 non-null   object
# ...

# %%
df['product_name']= df['product_name'].str.replace(' ','_')
df.sample(5)
# Out:
#       user_id group visit_date  conversion product_category  product_id  \
# 1630     1631     B 2022-03-02           0             home        1390
# 375       376     A 2022-02-07           0          fashion        1994
# 1230     1231     B 2022-02-16           0      electronics        1408
# 426       427     A 2022-03-31           0            books        1975
# 1556     1557     B 2022-02-17           0             home        1546
#
#      product_name  quantity   price discount  ... shipping_method region  \
# 1630        Chair         0   414,2     0,04  ...             NaN   West
# 375         Jeans         0  105,51     0,08  ...             NaN   East
# 1230       Laptop         0   958,3     0,25  ...             NaN  South
# 426       Mystery         0   18,99     0,28  ...             NaN  North
# 1556        Table         0   86,15     0,14  ...             NaN  South
#
#      customer_age customer_gender   device session_duration coupon_used  \
# ...

# %%
def minus (df, col):
    df[col] = df[col].str.lower()

# %%
minus(df, 'product_name')

# %% [markdown]
# ### cambiar comas por puntos y tipo float ###

# %%
def comas(df, col):
    df[col] = df[col].str.replace(',','.')
    df[col] = df[col].astype('float64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   user_id           2000 non-null   int64
#  1   group             2000 non-null   object
#  2   visit_date        2000 non-null   datetime64[ns]
#  3   conversion        2000 non-null   int64
#  4   product_category  2000 non-null   object
#  5   product_id        2000 non-null   int64
#  6   product_name      2000 non-null   object
#  7   quantity          2000 non-null   int64
#  8   price             1960 non-null   object
#  9   discount          1960 non-null   object
#  10  total_value       2000 non-null   object
#  11  payment_method    247 non-null    object
#  12  shipping_method   247 non-null    object
#  13  region            2000 non-null   object
#  14  customer_age      1960 non-null   float64
#  15  customer_gender   2000 non-null   object
# ...

# %% [markdown]
# ### espacios por guiones bajos ###

# %%
def espaciosguiones(df,col):
    df[col]= df[col].str.replace(' ','_')
    df.sample(5)

# %%
espaciosguiones(df,'payment_method')
espaciosguiones(df,'shipping_method')
minus(df,'payment_method')
minus(df,'shipping_method')

minus(df,'device')
minus(df,'referral_source')
minus(df,'browser')

df.sample(5)
# Out:
#       user_id group visit_date  conversion product_category  product_id  \
# 587       588     A 2022-02-25           0            books        1830
# 1054     1055     B 2022-01-15           0      electronics        1427
# 1815     1816     B 2022-01-15           0             toys        1736
# 1996     1997     B 2022-02-23           0          fashion        1474
# 733       734     B 2022-01-21           1            books        1767
#
#          product_name  quantity   price discount  ... shipping_method  \
# 587   science_fiction         0   22,83     0,18  ...             NaN
# 1054       headphones         0  811,91     0,07  ...             NaN
# 1815    action_figure         0   67,02     0,03  ...             NaN
# 1996            dress         0  109,75      0,2  ...             NaN
# 733           mystery         3   30,73      0,1  ...        same_day
#
#        region customer_age customer_gender   device session_duration  \
# ...

# %%
df['browser']=df_raw['Browser']
df.sample(5)
# Out:
#       user_id group visit_date  conversion product_category  product_id  \
# 1060     1061     B 2022-03-31           1           beauty        1209
# 1948     1949     A 2022-03-17           0           sports        1739
# 824       825     B 2022-02-24           1           sports        1734
# 527       528     A 2022-03-26           0           beauty        1753
# 463       464     B 2022-03-02           1             toys        1332
#
#        product_name  quantity   price discount  ... shipping_method region  \
# 1060         lotion         5   130,8      NaN  ...         express  South
# 1948  tennis_racket         0  208,03     0,12  ...             NaN  North
# 824        football         3    48,5     0,07  ...        same_day   East
# 527         perfume         0   97,71     0,18  ...             NaN  North
# 463          puzzle         3   47,88     0,08  ...         express   West
#
#      customer_age customer_gender   device session_duration coupon_used  \
# ...

# %% [markdown]
# ### map de browers ###

# %%
# diccionario de valores

dicc_map = {'Safaaaaari' : 'safari', 
            'Ottttther' : 'other', 
            'Firefoxxxxxx' : 'firefox', 
            'Eddddge' : 'edge', 
            'Chrooome' : 'chrome'}

# %%
df['browser'] = df['browser'].map(dicc_map)
df.sample(10)
# Out:
#       user_id group visit_date  conversion product_category  product_id  \
# 463       464     B 2022-03-02           1             toys        1332
# 237       238     A 2022-01-16           0             toys        1716
# 1935     1936     B 2022-01-27           1          fashion        1528
# 1524     1525     A 2022-03-06           0             home        1079
# 558       559     B 2022-01-24           0           sports        1849
# 1463     1464     B 2022-01-08           0          fashion        1843
# 249       250     B 2022-03-28           1             toys        1162
# 1440     1441     B 2022-03-10           0            books        1600
# 788       789     A 2022-03-07           0             home        1058
# 1868     1869     A 2022-03-14           0            books        1684
#
#        product_name  quantity   price discount  ... shipping_method   region  \
# 463          puzzle         3   47,88     0,08  ...         express     West
# ...

# %%
def minusglobal(df):
    for col in df.select_dtypes(include=['object']).columns:
        df[col] = df[col].str.lower()

# %%
minusglobal(df)
df.sample(5)
# Out:
#       user_id group visit_date  conversion product_category  product_id  \
# 955       956     a 2022-01-03           0          fashion        1305
# 1234     1235     b 2022-01-05           1             toys        1769
# 37         38     a 2022-02-26           1             toys        1143
# 606       607     a 2022-02-19           0      electronics        1995
# 1755     1756     b 2022-03-08           0          fashion        1540
#
#      product_name  quantity   price discount  ... shipping_method   region  \
# 955         dress         0   152,1     0,04  ...             NaN     west
# 1234         doll         3    19,0     0,29  ...         express    north
# 37           doll         3   19,99     0,21  ...        same_day     west
# 606    headphones         0  396,24     0,08  ...             NaN  central
# 1755        dress         0   120,4     0,02  ...             NaN    north
#
#      customer_age customer_gender   device session_duration coupon_used  \
# ...

# %%
df.to_csv('../data/data_limpios.csv', index=False)
