# %% [markdown]
# # Cosas a limpiar
#
# - **Visit Date** -> Cambiar a tipo fecha
# - **Conversion** -> ???
# - **Product Category** -> Cambiar a MINUS
# Cambiar FASHHION a FASHION
# - **Product Id** -> Cambia a NUMERICO
# - **Price** -> Tiene NULOS, Cambiar COMAS por PUNTOS y cambiar tipo FLOAT
# - **Discount** -> Tiene NULOS, Cambiar COMAS por PUNTOS y cambiar tipo FLOAT
# - **Total Value** -> Cambiar COMAS por PUNTOS y cambiar tipo FLOAT
# - **Payment Method** -> Tiene NULOS
# Cambiar ESPACIOS por "_"
# - **Shipping Method** -> Tiene NULOS
# Cambiar ESPACIOS por "_"
# - **Customer Age** -> Tiene NULOS
# - **Device** -> Cambiar a MINUS
# - **Coupon Used** -> Tiene NULOS
# - **Browser** -> Cambiar categorias porque estan mal escritas
# - **Referrral Source** -> Cambiar categorias porque estan mal escritas
# Cambiar a MINUS

# %%
import pandas as pd
df_raw = pd.read_csv('../data/data_raw.csv')
df_raw.sample(5)
# Out:
#       User Id Group  Visit Date  Conversion Product Category Product Id  \
# 477       478     B  2022-03-25           0             HOME      P1865
# 405       406     B  2022-03-31           0      ELECTRONICS      P1993
# 1888     1889     B  2022-01-03           1            BOOKS      P1690
# 1819     1820     A  2022-02-15           0             TOYS      P1580
# 148       149     A  2022-02-11           0            BOOKS      P1563
#
#        Product Name  Quantity   Price Discount  ...    Payment Method  \
# 477            Lamp         0  106,92      0,2  ...               NaN
# 405          Laptop         0  627,92     0,07  ...               NaN
# 1888          Novel         3   22,66     0,17  ...  Cash on Delivery
# 1819  Action Figure         0   40,99     0,03  ...               NaN
# 148       Biography         0   24,27     0,05  ...               NaN
#
#      Shipping Method Region Customer Age  Customer Gender   Device  \
# 477              NaN  North         60.0                F   TABLET
# 405              NaN  South         25.0                F  Desktop
# 1888         Express   East         29.0                M  Desktop
# 1819             NaN   West         43.0                F   Mobile
# 148              NaN   West         31.0                M   Mobile
#
#      Session Duration  Coupon Used     Browser Referral Source
# 477                 9          NaN   Ottttther            PAID
# 405                 7          NaN     Eddddge          Social
# 1888               22           No    Chrooome          Social
# 1819                7          NaN   Ottttther           Email
# 148                25          NaN  Safaaaaari           Email
#
# [5 rows x 21 columns]

# %% [markdown]
# ### COPIA DEL DATAFRAME ORIGINAL ###

# %%
df = df_raw.copy()

# %% [markdown]
# ### CAMBIO NOMBRES DE COLUMNAS ###

# %%
df.columns = df.columns.str.replace(' ','_').str.lower()
df.sample(5)
# Out:
#       user_id group  visit_date  conversion product_category product_id  \
# 789       790     B  2022-02-09           0         FASHHION      P1176
# 938       939     A  2022-01-16           0         FASHHION      P1970
# 1111     1112     A  2022-01-03           0             TOYS      P1981
# 1496     1497     B  2022-02-12           0           BEAUTY      P1203
# 862       863     B  2022-03-27           0             HOME      P1494
#
#      product_name  quantity   price discount  ... payment_method  \
# 789         Dress         0  146,71     0,21  ...            NaN
# 938         Dress         0   57,22     0,17  ...            NaN
# 1111         Doll         0   60,08     0,14  ...            NaN
# 1496      Mascara         0    35,8     0,29  ...            NaN
# 862         Table         0  224,18     0,18  ...            NaN
#
#      shipping_method   region customer_age  customer_gender   device  \
# 789              NaN    North         43.0                M   Mobile
# 938              NaN  Central         50.0                F   Mobile
# 1111             NaN  Central         52.0                M  Desktop
# 1496             NaN     East         41.0                M  Desktop
# 862              NaN    South         20.0                F   Mobile
#
#      session_duration  coupon_used     browser referral_source
# 789                 2          NaN   Ottttther          Social
# 938                18          NaN    Chrooome          Social
# 1111               22          NaN   Ottttther           Email
# 1496               23          NaN  Safaaaaari            PAID
# 862                30          NaN  Safaaaaari         Organic
#
# [5 rows x 21 columns]

# %% [markdown]
# ### CAMBIAR VISIT_DATE A FECHAS ###

# %%
df['visit_date'] = pd.to_datetime(df['visit_date'], format='%Y-%m-%d')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   user_id           2000 non-null   int64
#  1   group             2000 non-null   object
#  2   visit_date        2000 non-null   datetime64[ns]
#  3   conversion        2000 non-null   int64
#  4   product_category  2000 non-null   object
#  5   product_id        2000 non-null   object
#  6   product_name      2000 non-null   object
#  7   quantity          2000 non-null   int64
#  8   price             1960 non-null   object
#  9   discount          1960 non-null   object
#  10  total_value       2000 non-null   object
#  11  payment_method    247 non-null    object
#  12  shipping_method   247 non-null    object
#  13  region            2000 non-null   object
#  14  customer_age      1960 non-null   float64
#  15  customer_gender   2000 non-null   object
#  16  device            2000 non-null   object
#  17  session_duration  2000 non-null   int64
#  18  coupon_used       247 non-null    object
#  19  browser           2000 non-null   object
#  20  referral_source   2000 non-null   object
# dtypes: datetime64[ns](1), float64(1), int64(4), object(15)
# memory usage: 328.3+ KB

# %% [markdown]
# ### crear una columna nueva ###

# %%
df['conversion_str'] = df['conversion'].apply(lambda x: 'yes' if x == 1 else 'no')
df.sample(10)
# Out:
#       user_id group visit_date  conversion product_category product_id  \
# 1195     1196     B 2022-03-31           0           SPORTS      P1695
# 391       392     A 2022-02-03           0             TOYS      P1901
# 25         26     B 2022-03-23           0           BEAUTY      P1600
# 1388     1389     B 2022-03-24           0           BEAUTY      P1981
# 982       983     A 2022-01-14           0             TOYS      P1013
# 1902     1903     B 2022-01-16           0           BEAUTY      P1710
# 498       499     B 2022-02-20           0         FASHHION      P1708
# 1090     1091     B 2022-03-16           0      ELECTRONICS      P1753
# 1639     1640     B 2022-01-22           0         FASHHION      P1948
# 1465     1466     A 2022-03-03           0           BEAUTY      P1915
#
#        product_name  quantity   price discount  ... shipping_method   region  \
# 1195       Football         0  225,27     0,03  ...             NaN    South
# 391   Action Figure         0   82,74     0,13  ...             NaN    South
# 25          Perfume         0   26,39     0,07  ...             NaN    South
# 1388       Lipstick         0     NaN     0,21  ...             NaN    South
# 982          Puzzle         0   84,02      0,3  ...             NaN     East
# 1902        Mascara         0   109,7     0,16  ...             NaN    South
# 498         T-shirt         0   65,86     0,01  ...             NaN    South
# 1090     Smartphone         0  622,05     0,16  ...             NaN    South
# 1639        T-shirt         0  194,46     0,16  ...             NaN  Central
# 1465       Lipstick         0   104,1     0,14  ...             NaN     East
#
#      customer_age customer_gender   device session_duration coupon_used  \
# 1195         46.0               M   Mobile               10         NaN
# 391          40.0               F  Desktop               10         NaN
# 25           63.0               M   TABLET               23         NaN
# 1388         42.0               M   TABLET               21         NaN
# 982          39.0               M  Desktop               23         NaN
# 1902         41.0               M  Desktop               20         NaN
# 498          39.0               F   TABLET               20         NaN
# 1090         51.0               M   TABLET                4         NaN
# 1639         20.0               M   Mobile               26         NaN
# 1465         34.0               F   Mobile               22         NaN
#
#            browser referral_source conversion_str
# 1195  Firefoxxxxxx          Social             no
# 391      Ottttther            PAID             no
# 25    Firefoxxxxxx          Social             no
# 1388  Firefoxxxxxx         Organic             no
# 982        Eddddge          Social             no
# 1902     Ottttther            PAID             no
# 498       Chrooome            PAID             no
# 1090  Firefoxxxxxx            PAID             no
# 1639  Firefoxxxxxx           Email             no
# 1465    Safaaaaari            PAID             no
#
# [10 rows x 22 columns]

# %% [markdown]
# ### sacar solo unas columnas ###

# %%
df.loc[:,['conversion','conversion_str']]
# Out:
#       conversion conversion_str
# 0              0             no
# 1              0             no
# 2              0             no
# 3              1            yes
# 4              0             no
# ...          ...            ...
# 1995           0             no
# 1996           0             no
# 1997           0             no
# 1998           0             no
# 1999           0             no
#
# [2000 rows x 2 columns]

# %% [markdown]
# ### cambia a MINUSCULAS ###

# %%
df['product_category']= df['product_category'].str.lower()

# %% [markdown]
# ### CAMBIAR FASHHION por FASHION ###

# %%
df['product_category']= df['product_category'].str.replace('fashhion','fashion')
df['product_category'].value_counts()
# Out:
# product_category
# fashion        321
# books          291
# home           287
# sports         282
# toys           276
# electronics    275
# beauty         268
# Name: count, dtype: int64

# %% [markdown]
# ### cambiar a numero ###

# %%
df['product_id']= df['product_id'].str.replace('P','')
df.sample(5)
df['product_id']= df['product_id'].astype('int64')
df.info()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 df['product_id']= df['product_id'].str.replace('P','')
#       2 df.sample(5)
#       3 df['product_id']= df['product_id'].astype('int64')
#
# File c:\Users\jesus\anaconda3\Lib\site-packages\pandas\core\generic.py:6321, in NDFrame.__getattr__(self, name)
#    6314 if (
#    6315     name not in self._internal_names_set
#    6316     and name not in self._metadata
#    6317     and name not in self._accessors
#    6318     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319 ):
#    6320     return self[name]
# -> 6321 return object.__getattribute__(self, name)
#
# File c:\Users\jesus\anaconda3\Lib\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# --> 224 accessor_obj = self._accessor(obj)
#     225 # Replace the property with the accessor object. Inspired by:
#     226 # https://www.pydanny.com/cached-property.html
#     227 # We need to use object.__setattr__ because we overwrite __setattr__ on
#     228 # NDFrame
#     229 object.__setattr__(obj, self._name, accessor_obj)
#
# File c:\Users\jesus\anaconda3\Lib\site-packages\pandas\core\strings\accessor.py:194, in StringMethods.__init__(self, data)
#     191 def __init__(self, data) -> None:
#     192     from pandas.core.arrays.string_ import StringDtype
# --> 194     self._inferred_dtype = self._validate(data)
#     195     self._is_categorical = isinstance(data.dtype, CategoricalDtype)
#     196     self._is_string = isinstance(data.dtype, StringDtype)
#
# File c:\Users\jesus\anaconda3\Lib\site-packages\pandas\core\strings\accessor.py:248, in StringMethods._validate(data)
#     245 inferred_dtype = lib.infer_dtype(values, skipna=True)
#     247 if inferred_dtype not in allowed_types:
# --> 248     raise AttributeError("Can only use .str accessor with string values!")
#     249 return inferred_dtype
#
# AttributeError: Can only use .str accessor with string values!

# %%
df['product_name']= df['product_name'].str.replace(' ','_')
df.sample(5)
# Out:
#       user_id group visit_date  conversion product_category  product_id  \
# 48         49     B 2022-02-18           0             toys        1274
# 978       979     A 2022-01-24           0           beauty        1433
# 1699     1700     B 2022-01-06           0            books        1259
# 1332     1333     A 2022-03-04           0      electronics        1885
# 271       272     B 2022-01-06           0          fashion        1425
#
#        product_name  quantity   price discount  ...   region customer_age  \
# 48    Action_Figure         0   68,33     0,23  ...     East         18.0
# 978         Perfume         0  117,55     0,14  ...     West         61.0
# 1699          Novel         0   25,74     0,28  ...  Central         35.0
# 1332         Laptop         0  982,86     0,22  ...     East         61.0
# 271           Jeans         0  120,86     0,13  ...     East         69.0
#
#      customer_gender   device  session_duration coupon_used     browser  \
# 48                 M   Mobile                12         NaN  Safaaaaari
# 978                F  Desktop                 8         NaN   Ottttther
# 1699               F   Mobile                17         NaN   Ottttther
# 1332               F   TABLET                26         NaN     Eddddge
# 271                F   Mobile                 4         NaN     Eddddge
#
#       referral_source conversion_str producti_id
# 48            Organic             no        1274
# 978             Email             no        1433
# 1699          Organic             no        1259
# 1332            Email             no        1885
# 271             Email             no        1425
#
# [5 rows x 23 columns]

# %%
def minus (df, col):
    df[col] = df[col].str.lower()

# %%
minus(df, 'product_name')

# %% [markdown]
# ### cambiar comas por puntos y tipo float ###

# %%
def comas(df, col):
    df[col] = df[col].str.replace(',','.')
    df[col] = df[col].astype('float64')

# %%
comastipo(df, 'price')
df.sample(5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[105], line 1
# ----> 1 comastipo(df, 'price')
#       2 df.sample(5)
#
# Cell In[92], line 2, in comastipo(df, col)
#       1 def comastipo(df, col):
# ----> 2     df[col] = df[col].str.replace(',','.')
#       3     df[col] = df[col].astype('float64')
#
# File c:\Users\jesus\anaconda3\Lib\site-packages\pandas\core\generic.py:6321, in NDFrame.__getattr__(self, name)
#    6314 if (
#    6315     name not in self._internal_names_set
#    6316     and name not in self._metadata
#    6317     and name not in self._accessors
#    6318     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319 ):
#    6320     return self[name]
# -> 6321 return object.__getattribute__(self, name)
#
# File c:\Users\jesus\anaconda3\Lib\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# --> 224 accessor_obj = self._accessor(obj)
#     225 # Replace the property with the accessor object. Inspired by:
#     226 # https://www.pydanny.com/cached-property.html
#     227 # We need to use object.__setattr__ because we overwrite __setattr__ on
#     228 # NDFrame
#     229 object.__setattr__(obj, self._name, accessor_obj)
#
# File c:\Users\jesus\anaconda3\Lib\site-packages\pandas\core\strings\accessor.py:194, in StringMethods.__init__(self, data)
#     191 def __init__(self, data) -> None:
#     192     from pandas.core.arrays.string_ import StringDtype
# --> 194     self._inferred_dtype = self._validate(data)
#     195     self._is_categorical = isinstance(data.dtype, CategoricalDtype)
#     196     self._is_string = isinstance(data.dtype, StringDtype)
#
# File c:\Users\jesus\anaconda3\Lib\site-packages\pandas\core\strings\accessor.py:248, in StringMethods._validate(data)
#     245 inferred_dtype = lib.infer_dtype(values, skipna=True)
#     247 if inferred_dtype not in allowed_types:
# --> 248     raise AttributeError("Can only use .str accessor with string values!")
#     249 return inferred_dtype
#
# AttributeError: Can only use .str accessor with string values!

# %%
comastipo(df, 'discount')
df.sample(5)
# Out:
#       user_id group visit_date  conversion product_category  product_id  \
# 1211     1212     A 2022-02-28           0            books        1210
# 999      1000     A 2022-01-16           0             toys        1850
# 991       992     B 2022-01-29           0             home        1171
# 1028     1029     A 2022-03-16           0      electronics        1191
# 166       167     A 2022-03-11           0           sports        1270
#
#        product_name  quantity   price  discount  ...   region customer_age  \
# 1211      biography         0   46.96      0.11  ...  Central         20.0
# 999          puzzle         0    5.18      0.02  ...    South         67.0
# 991           table         0  400.81      0.23  ...    North         39.0
# 1028         laptop         0  263.05      0.13  ...     West         69.0
# 166   running_shoes         0  258.80      0.24  ...     West         19.0
#
#      customer_gender   device  session_duration coupon_used       browser  \
# 1211               F  Desktop                16         NaN     Ottttther
# 999                M   TABLET                17         NaN      Chrooome
# 991                F   TABLET                 7         NaN     Ottttther
# 1028               F  Desktop                26         NaN  Firefoxxxxxx
# 166                F   Mobile                13         NaN  Firefoxxxxxx
#
#       referral_source conversion_str producti_id
# 1211          Organic             no        1210
# 999              PAID             no        1850
# 991            Social             no        1171
# 1028          Organic             no        1191
# 166           Organic             no        1270
#
# [5 rows x 23 columns]

# %%
comastipo(df, 'total_value')
df.sample(5)
# Out:
#       user_id group visit_date  conversion product_category  product_id  \
# 417       418     A 2022-02-18           0             home        1547
# 589       590     A 2022-03-06           0           beauty        1842
# 1385     1386     A 2022-01-06           0             toys        1725
# 300       301     A 2022-02-14           0      electronics        1167
# 543       544     B 2022-03-01           0           beauty        1939
#
#      product_name  quantity   price  discount  ...  region customer_age  \
# 417          lamp         0   53.86      0.05  ...   South         39.0
# 589       mascara         0   88.51      0.06  ...   South         22.0
# 1385       puzzle         0   89.38      0.29  ...   North         28.0
# 300    headphones         0  849.45      0.08  ...    West         52.0
# 543       perfume         0   35.13      0.08  ...   North         49.0
#
#      customer_gender   device  session_duration coupon_used     browser  \
# 417                F   Mobile                22         NaN    Chrooome
# 589                M   Mobile                27         NaN   Ottttther
# 1385               M  Desktop                22         NaN  Safaaaaari
# 300                F   TABLET                 6         NaN   Ottttther
# 543                F   TABLET                 8         NaN   Ottttther
#
#       referral_source conversion_str producti_id
# 417           Organic             no        1547
# 589              PAID             no        1842
# 1385            Email             no        1725
# 300            Social             no        1167
# 543            Social             no        1939
#
# [5 rows x 23 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   user_id           2000 non-null   int64
#  1   group             2000 non-null   object
#  2   visit_date        2000 non-null   datetime64[ns]
#  3   conversion        2000 non-null   int64
#  4   product_category  2000 non-null   object
#  5   product_id        2000 non-null   int64
#  6   product_name      2000 non-null   object
#  7   quantity          2000 non-null   int64
#  8   price             1960 non-null   float64
#  9   discount          1960 non-null   float64
#  10  total_value       2000 non-null   float64
#  11  payment_method    247 non-null    object
#  12  shipping_method   247 non-null    object
#  13  region            2000 non-null   object
#  14  customer_age      1960 non-null   float64
#  15  customer_gender   2000 non-null   object
#  16  device            2000 non-null   object
#  17  session_duration  2000 non-null   int64
#  18  coupon_used       247 non-null    object
#  19  browser           2000 non-null   object
#  20  referral_source   2000 non-null   object
#  21  conversion_str    2000 non-null   object
#  22  producti_id       2000 non-null   int64
# dtypes: datetime64[ns](1), float64(4), int64(6), object(12)
# memory usage: 359.5+ KB

# %% [markdown]
# ### espacios por guiones bajos ###

# %%
def espaciosguiones(df,col):
    df[col]= df[col].str.replace(' ','_')
    df.sample(5)

# %%
espaciosguiones(df,'payment_method')
espaciosguiones(df,'shipping_method')
minus(df,'payment_method')
minus(df,'shipping_method')

minus(df,'device')
minus(df,'referral_source')
minus(df,'browser')

df.sample(5)
# Out:
#       user_id group visit_date  conversion product_category  product_id  \
# 484       485     B 2022-03-23           0          fashion        1098
# 1555     1556     A 2022-01-06           0             toys        1624
# 905       906     B 2022-02-16           1           beauty        1923
# 96         97     B 2022-03-04           0      electronics        1737
# 1596     1597     A 2022-02-02           0            books        1071
#
#      product_name  quantity   price  discount  ...   region customer_age  \
# 484      sneakers         0  100.64      0.10  ...  Central         46.0
# 1555   board_game         0   57.70      0.12  ...    North         56.0
# 905       mascara         2   67.68      0.21  ...    South         24.0
# 96         camera         0  686.37      0.15  ...    South         26.0
# 1596    biography         0   39.62      0.24  ...    North         45.0
#
#      customer_gender   device  session_duration coupon_used     browser  \
# 484                M  desktop                17         NaN    chrooome
# 1555               F   tablet                27         NaN   ottttther
# 905                F  desktop                 7          No  safaaaaari
# 96                 M   tablet                28         NaN     eddddge
# 1596               M   mobile                28         NaN   ottttther
#
#       referral_source conversion_str producti_id
# 484             email             no        1098
# 1555            email             no        1624
# 905            social            yes        1923
# 96             social             no        1737
# 1596          organic             no        1071
#
# [5 rows x 23 columns]

# %%
df['browser']=df_raw['Browser']
df.sample(5)
# Out:
#       user_id group visit_date  conversion product_category  product_id  \
# 1529     1530     B 2022-02-22           0      electronics        1758
# 1148     1149     B 2022-03-07           0          fashion        1831
# 552       553     B 2022-01-23           0          fashion        1138
# 787       788     A 2022-01-16           0             toys        1463
# 971       972     B 2022-02-13           0           sports        1616
#
#        product_name  quantity   price  discount  ...  region customer_age  \
# 1529         camera         0  726.05      0.12  ...    East         58.0
# 1148       sneakers         0   86.62      0.12  ...   South         31.0
# 552           dress         0  182.75      0.04  ...    West         68.0
# 787   action_figure         0     NaN      0.26  ...   South         55.0
# 971        football         0  114.67      0.21  ...   South         22.0
#
#      customer_gender   device  session_duration coupon_used    browser  \
# 1529               M   tablet                14         NaN    Eddddge
# 1148               F   tablet                27         NaN  Ottttther
# 552                F   tablet                22         NaN    Eddddge
# 787                F   mobile                24         NaN   Chrooome
# 971                M  desktop                23         NaN  Ottttther
#
#       referral_source conversion_str producti_id
# 1529            email             no        1758
# 1148             paid             no        1831
# 552              paid             no        1138
# 787            social             no        1463
# 971           organic             no        1616
#
# [5 rows x 23 columns]

# %% [markdown]
# ### map de browers ###

# %%
# diccionario de valores

dicc_map = {'Safaaaaari' : 'safari', 
            'Ottttther' : 'other', 
            'Firefoxxxxxx' : 'firefox', 
            'Eddddge' : 'edge', 
            'Chrooome' : 'chrome'}

# %%
df['browser'] = df['browser'].map(dicc_map)
df.sample(10)
# Out:
#       user_id group visit_date  conversion product_category  product_id  \
# 1038     1039     A 2022-01-29           1             home        1599
# 630       631     B 2022-01-13           0             toys        1229
# 1670     1671     A 2022-03-09           1            books        1089
# 1571     1572     A 2022-01-26           0      electronics        1569
# 1529     1530     B 2022-02-22           0      electronics        1758
# 199       200     B 2022-02-13           0            books        1605
# 1063     1064     A 2022-01-26           0             toys        1742
# 928       929     B 2022-02-10           0             toys        1663
# 1252     1253     A 2022-01-27           1           beauty        1808
# 1469     1470     B 2022-03-07           0             home        1056
#
#          product_name  quantity   price  discount  ...   region customer_age  \
# 1038             sofa         5  156.62      0.23  ...     West         53.0
# 630              doll         0   73.37      0.09  ...  Central         25.0
# 1670  science_fiction         1   49.97      0.02  ...  Central         70.0
# 1571       smartphone         0  466.89      0.03  ...  Central         68.0
# 1529           camera         0  726.05      0.12  ...     East         58.0
# 199             novel         0   13.64      0.12  ...  Central         24.0
# 1063           puzzle         0   98.10      0.24  ...    North         66.0
# 928            puzzle         0   31.11      0.22  ...    South         58.0
# 1252          perfume         2   14.50      0.26  ...  Central         29.0
# 1469             lamp         0  222.26      0.07  ...    North         61.0
#
#      customer_gender   device  session_duration coupon_used  browser  \
# 1038               F   tablet                15          No   chrome
# 630                F  desktop                 6         NaN     edge
# 1670               M   mobile                30          No     edge
# 1571               M   tablet                18         NaN  firefox
# 1529               M   tablet                14         NaN     edge
# 199                M   tablet                17         NaN    other
# 1063               M   mobile                12         NaN     edge
# 928                F  desktop                13         NaN     edge
# 1252               F  desktop                27         Yes  firefox
# 1469               M  desktop                17         NaN     edge
#
#       referral_source conversion_str producti_id
# 1038          organic            yes        1599
# 630             email             no        1229
# 1670          organic            yes        1089
# 1571           social             no        1569
# 1529            email             no        1758
# 199           organic             no        1605
# 1063             paid             no        1742
# 928            social             no        1663
# 1252            email            yes        1808
# 1469          organic             no        1056
#
# [10 rows x 23 columns]
